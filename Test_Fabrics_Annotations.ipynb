# %% [markdown]
# <a href="https://colab.research.google.com/github/ionutpopa/image-duplicator-remover-api/blob/main/Test_Fabrics_Annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U gdown

# %%
# !gdown --id 1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z
# From (redirected): https://drive.google.com/uc?id=1G_g3NEcluW9iKbWY6BiCMcSo0eLxCG0z&confirm=t&uuid=47894fbb-1f12-4660-8ca3-e52646ee6f17
# To: /content/fabric.tar.gz
# 100% 13.0G/13.0G [04:00<00:00, 54.0MB/s]

# %%
# !tar -xvzf fabric.tar.gz -C fabrics_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
# ./fabric/test/chiffon/289725_imaterial.jpeg
# ./fabric/test/chiffon/289927_imaterial.jpeg
# ./fabric/test/chiffon/290071_imaterial.jpeg
# ./fabric/test/chiffon/290113_imaterial.jpeg
# ./fabric/test/chiffon/290367_imaterial.jpeg
# ./fabric/test/chiffon/290458_imaterial.jpeg
# ./fabric/test/chiffon/290703_imaterial.jpeg
# ./fabric/test/chiffon/291067_imaterial.jpeg
# ./fabric/test/chiffon/291235_imaterial.jpeg
# ./fabric/test/chiffon/291463_imaterial.jpeg
# ./fabric/test/chiffon/2918_imaterial.jpeg
# ./fabric/test/chiffon/291922_imaterial.jpeg
# ./fabric/test/chiffon/291998_imaterial.jpeg
# ./fabric/test/chiffon/29256_imaterial.jpeg
# ./fabric/test/chiffon/292922_imaterial.jpeg
# ./fabric/test/chiffon/2930_imaterial.jpeg
# ./fabric/test/chiffon/293250_imaterial.jpeg
# ./fabric/test/chiffon/293260_imaterial.jpeg
# ./fabric/test/chiffon/293773_imaterial.jpeg
# ./fabric/test/chiffon/293845_imaterial.jpeg
# ...

# %%
# !rm -rf fabrics_dataset

# %%
# !python cleaner.py
# Out:
# Deleting 'serge' with only 528 images.
# Deleting 'neoprene' with only 184 images.
# Deleting 'plush' with only 209 images.
# Deleting 'canvas' with only 12 images.
# Deleting 'twill' with only 31 images.
# Deleting 'lawn' with only 928 images.
# Deleting 'taffeta' with only 810 images.
# Deleting 'vinyl' with only 202 images.
# Deleting 'chenille' with only 809 images.

# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import os

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ...

# %% [markdown]
# 18 clase au ramas

# %%
# !pip install -q transformers pillow tqdm

# %%
# !python annotator.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing valentino-eclectic-pink-tweed-top.jpeg in tweed
# Processing albers%20lilac%20tweed%20shift%20dress.jpg in tweed
# Processing elena-sparkly-tweed-shorts-851_800x.jpg in tweed
# Processing queen_of_jetlag_tweed_blazer_1628-000076-0021_01a.jpg in tweed
# Processing nova_tweed_pants_in_white_fash_1622772810_f7380aff.jpg in tweed
# Processing sandro_sfpju00570-60_v_1.jpg in tweed
# Processing rc40-main-glynn.jpg in tweed
# Processing beautiful-stylish-girl-dark-hair-hugging-potted-plant-wearing-soft-pink-pullover-tweed-shorts-romantic-portrait-151032478.jpg in tweed
# Processing charlie-luciano-tweed-overshirt-1_11c6ac95-7785-4ce0-b606-7f93bdcfea11_800x.jpg in tweed
# Processing tweed-blazer-mob.jpg.png in tweed
# Processing akk94853_black_xl.jpg in tweed
# Processing 19fw_4276_2.jpg.png in tweed
# Processing 15381263713662343255__53623.1552410778.jpg in tweed
# ...
